# [(146, 399), (163, 403), (170, 393), (169, 391), (166, 386), (170, 381), (170, 371), (170, 355), (169, 346), (167, 335), (170, 329), (170, 320), (170, 310), (171, 301), (173, 290), (178, 289), (182, 287), (188, 286), (190, 286), (192, 291), (194, 296), (195, 305), (194, 307), (191, 312), (190, 316), (190, 321), (192, 331), (193, 338), (196, 341), (197, 346), (199, 352), (198, 360), (197, 366), (197, 373), (196, 380), (197, 383), (196, 387), (192, 389), (191, 392), (190, 396), (189, 400), (194, 401), (201, 402), (208, 403), (213, 402), (216, 401), (219, 397), (219, 393), (216, 390), (215, 385), (215, 379), (213, 373), (213, 365), (212, 360), (210, 353), (210, 347), (212, 338), (213, 329), (214, 319), (215, 311), (215, 306), (216, 296), (218, 290), (221, 283), (225, 282), (233, 284), (238, 287), (243, 290), (250, 291), (255, 294), (261, 293), (265, 291), (271, 291), (273, 289), (278, 287), (279, 285), (281, 280), (284, 278), (284, 276), (287, 277), (289, 283), (291, 286), (294, 291), (
# ...

# %%
len('...')
len('...')

def A005150(n):
    p = "1"
    seq = [1]
    while (n > 1):
        q = ''
        idx = 0 # Index
        l = len(p) # Length
        while idx < l:
            start = idx
            idx = idx + 1
            while idx < l and p[idx] == p[start]:
                idx = idx + 1
            q = q + str(idx-start) + p[start]
        n, p = n - 1, q
        seq.append(int(p))
    return seq

n = 30
print len(str(A005150(n+1)[n]))
# Out:
# 5808

# %%
file = open('evil2.gfx','r')
file.read()
list = bytearray(file.read())
list_1 = list[2::5]
list_2 = list[3::5]   
# print ' '.join(str(x) for x in list_1)
# print
# print '\n'.join(format(x, 'b').zfill(8) for x in list_2)
# 330 = 22*15
# plt.scatter(list_1,list_2)
print len(list_1)
print len(list_2)

row = 30
col = 11
img = []
for i in range(row):
    img.append(list_1[(0+i*col):(col+i*col)])

import numpy as np
import matplotlib.pyplot as plt

plt.gray()
plt.imshow(img)
# Out:
# 330
# 330

# %%
import base64
import imghdr
import urllib2
from cStringIO import StringIO

pcurl = 'http://www.pythonchallenge.com/pc/return/'
img_url = 'http://www.pythonchallenge.com/pc/return/evil2.gfx'

request = urllib2.Request(img_url)
base64string = base64.encodestring('{0}:{1}'.format('huge',
                                                    'file')).replace('\n', '')
request.add_header("Authorization", "Basic {0}".format(base64string))
img = urllib2.urlopen(request)
with open('evil2.gfx', 'wb') as img_file:
    img_file.write(img.read())

# if we take a look to the gfx file header:
gfx_file = open('evil2.gfx', 'rb').read()
print "The .gfx file's header:\n"
print ' '.join(['{0:02X}'.format(ord(char)) for char in gfx_file[:15]])
print

# We can se this:
# FF 89 47 89 FF D8 50 49 50 D8 FF 4E 46 4E FF
#
# These are various file magic numbers (signature) for some image file formats:
#
# GIF (87a):    47 49 46 38 37 61
# JPEG:         FF D8
# PNG:          89 50 4E 47 0D 0A 1A 0A
#
# Now let's take a closer look to the .gfx's header:
#
# FF 1ˢᵗ byte of JPEG signature
# 89 1ˢᵗ byte of PNG signature
# 47 1ˢᵗ byte of GIF signature
# 89 1ˢᵗ byte of PNG signature
# FF 1ˢᵗ byte of JPEG signature
# -------------------------------
# D8 2ⁿᵈ byte of JPEG signature
# 50 2ⁿᵈ byte of PNG signature
# 49 2ⁿᵈ byte of GIF signature
# 50 2ⁿᵈ byte of PNG signature
# D8 2ⁿᵈ byte of JPEG signature
# -------------------------------
# FF 1ˢᵗ byte of data of a JPEG file
# 4E 3ʳᵈ byte of PNG signature
# 46 3ʳᵈ byte of GIF signature
# 4E 3ʳᵈ byte of PNG signature
# FF 1ˢᵗ byte of data of a JPEG file
# ...
#
# So, seems clear to me that we have 5 images multiplexed in one file.

hidden_images = {n: '' for n in xrange(5)}

for i in xrange(5):
    hidden_images[i] = gfx_file[i::5]

filetype = {0: 'jpeg', 1: 'png', 2: 'gif', 3: 'png', 4: 'jpeg'}

for image, raw_data in hidden_images.items():
    if imghdr.what(StringIO(raw_data)) in ('jpeg', 'png', 'gif'):
        filename = 'evil_hidden_{0}.{1}'.  format(image, filetype[image])
        with open(filename, 'wb') as out:
            out.write(raw_data)
# Out:
# The .gfx file's header:
#
# FF 89 47 89 FF D8 50 49 50 D8 FF 4E 46 4E FF

# %%
import os
print os.stat("wire.png")
# Out:
# nt.stat_result(st_mode=33206, st_ino=0L, st_dev=0L, st_nlink=0, st_uid=0, st_gid=0, st_size=15936L, st_atime=1549270683L, st_mtime=1549270692L, st_ctime=1549270691L)

# %%
from PIL import Image

im = Image.open('wire.png') # Can be many different formats.
pix = im.load()
print im.size  # Get the width and hight of the image for iterating over
print pix[0,0]  # Get the RGBA Value of the a pixel of an image

def go_round():
    l = 0
    size = 100
    while l < 99:
        for i in range(99-2*l):
            x = i+l
            y = l
            print "right x: {}, y: {}".format(x,y)
            #print pix[x+y*size, 0]
        for i in range(99-2*l):
            x = 99-l
            y = i+l
            print "down  x: {}, y: {}".format(x,y)
            #print pix[x+y*size, 0]
        for i in range(99-2*l):
            x = (99-l)-(i+l)
            y = (99-l)
            print "left  x: {}, y: {}".format(x,y)
            #print pix[x+y*size, 0]
        for i in range(99-2*l):
            x = l
            y = (99-l)-(i+l)
            print "up    x: {}, y: {}".format(x,y)
            #print pix[x+y*size, 0]
        l+=1
    
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

def main():
    numframes = 100
    numpoints = 10000
    color_data = np.random.random((numframes, numpoints))
    x, y, c = np.random.random((3, numpoints))

    fig = plt.figure()
    scat = plt.scatter(x, y, s=100)

    ani = animation.FuncAnimation(fig, update_plot, frames=xrange(numframes),
                                  fargs=(color_data, scat))
    plt.show()

def update_plot(i, data, scat):
    scat.set_array(data[i])
    return scat,

main()
# Out:
# (10000, 1)
# (193, 176, 150)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2df893237d37> in <module>()
#      53     return scat,
#      54
# ---> 55 main()
#
# <ipython-input-1-2df893237d37> in main()
#      47     ani = animation.FuncAnimation(fig, update_plot, frames=xrange(numframes),
#      48                                   fargs=(color_data, scat))
# ---> 49     plt.show()
#      50
#      51 def update_plot(i, data, scat):
#
# C:\Users\Kibo\Anaconda3\envs\py27\lib\site-packages\matplotlib\pyplot.pyc in show(*args, **kw)
#     242     """
#     243     global _show
# --> 244     return _show(*args, **kw)
#     245
#     246
#
# C:\Users\Kibo\Anaconda3\envs\py27\lib\site-packages\ipykernel\pylab\backend_inline.pyc in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ...

# %%
# 83051 -> (%90 or Z) -> 72758
# 60092
import re
import urllib2
response = urllib2.urlopen("http://www.pythonchallenge.com/pc/def/linkedlist.php?busynothing=12345")
html = response.read()
new = html.decode("utf-8")[-5:]
# print(html)

import cookielib
import urllib2

cookies = cookielib.LWPCookieJar()
handlers = [
    urllib2.HTTPHandler(),
    urllib2.HTTPSHandler(),
    urllib2.HTTPCookieProcessor(cookies)
    ]
opener = urllib2.build_opener(*handlers)

def fetch(uri):
    req = urllib2.Request(uri)
    return opener.open(req)
all_vals = []
all_names = []
def dump():
    for cookie in cookies:
        # print(cookie.name, cookie.value)
        all_vals.append(cookie.value)
        all_names.append(cookie.name)

uri = 'http://www.pythonchallenge.com/pc/def/linkedlist.php?busynothing=12345'
res = fetch(uri)
dump()

for i in range(400):
    new_url = "http://www.pythonchallenge.com/pc/def/linkedlist.php?busynothing=" + str(new)
    # print(new_url)
    
    response = urllib2.urlopen(new_url, timeout=1000)
    r = response.read()
    new = re.sub('[^0-9]','', r.decode("utf-8")[-5:])
    # print(r)
    res = fetch(new_url)
    dump()
    if new == "":
        break
print(response.read())
print(all_vals)
# print(all_names)
# Out:
# If you came here from level 4 - go back!<br>You should follow the obvious chain...<br><br>and the next busynothing is 44827
#
# ['B', 'Z', 'h', '9', '1', 'A', 'Y', '%26', 'S', 'Y', '%94', '%3A', '%E2', 'I', '%00', '%00', '%21', '%19', '%80', 'P', '%81', '%11', '%00', '%AF', 'g', '%9E', '%A0', '+', '%00', 'h', 'E', '%3D', 'M', '%B5', '%23', '%D0', '%D4', '%D1', '%E2', '%8D', '%06', '%A9', '%FA', '%26', 'S', '%D4', '%D3', '%21', '%A1', '%EA', 'i', '7', 'h', '%9B', '%9A', '%2B', '%BF', '%60', '%22', '%C5', 'W', 'X', '%E1', '%AD', 'L', '%80', '%E8', 'V', '%3C', '%C6', '%A8', '%DB', 'H', '%26', '3', '2', '%18', '%A8', 'x', '%01', '%08', '%21', '%8D', 'S', '%0B', '%C8', '%AF', '%96', 'K', 'O', '%CA', '2', '%B0', '%F1', '%BD', '%1D', 'u', '%A0', '%86', '%05', '%92', 's', '%B0', '%92', '%C4', 'B', 'c', '%F1', 'w', '%24', 'S', '%85', '%09', '%09', 'C', '%AE', '%24', '%90']
# ...

# %%
out = [
    'B', 'Z', 'h', '9', '1', 'A', 'Y', '%26', 'S', 'Y', '%94', '%3A', '%E2', 'I', '%00', '%00', '%21', '%19', '%80',
    'P', '%81', '%11', '%00', '%AF', 'g', '%9E', '%A0', '+', '%00', 'h', 'E', '%3D', 'M', '%B5', '%23', '%D0', '%D4',
    '%D1', '%E2', '%8D', '%06', '%A9', '%FA', '%26', 'S', '%D4', '%D3', '%21', '%A1', '%EA', 'i', '7', 'h', '%9B',
    '%9A', '%2B', '%BF', '%60', '%22', '%C5', 'W', 'X', '%E1', '%AD', 'L', '%80', '%E8', 'V', '%3C', '%C6', '%A8',
    '%DB', 'H', '%26', '3', '2', '%18', '%A8', 'x', '%01', '%08', '%21', '%8D', 'S', '%0B', '%C8', '%AF', '%96', 'K',
    'O', '%CA', '2', '%B0', '%F1', '%BD', '%1D', 'u', '%A0', '%86', '%05', '%92', 's', '%B0', '%92', '%C4', 'B', 'c',
    '%F1', 'w', '%24', 'S', '%85', '%09', '%09', 'C', '%AE', '%24', '%90'
]

txt = str.join("", out)
new = ""
i = 0

while i < len(txt):
    if txt[i] == "%":
        new += "\\x"+ txt[i+1:i+3]
        i += 3
    else:
        new += txt[i]
        i += 1
# print new
        
percent   = b'BZh91AY%26SY%94%3A%E2I%00%00%21%19%80P%81%11%00%AFg%9E%A0+%00hE%3DM%B5%23%D0%D4%D1%E2%8D%06%A9%FA%26S%D4%D3%21%A1%EAi7h%9B%9A%2B%BF%60%22%C5WX%E1%ADL%80%E8V%3C%C6%A8%DBH%2632%18%A8x%01%08%21%8DS%0B%C8%AF%96KO%CA2%B0%F1%BD%1Du%A0%86%05%92s%B0%92%C4Bc%F1w%24S%85%09%09C%AE%24%90'
clean     = b'BZh91AY\x26SY\x94\x3A\xE2I\x00\x00\x21\x19\x80P\x81\x11\x00\xAFg\x9E\xA0+\x00hE\x3DM\xB5\x23\xD0\xD4\xD1\xE2\x8D\x06\xA9\xFA\x26S\xD4\xD3\x21\xA1\xEAi7h\x9B\x9A\x2B\xBF\x60\x22\xC5WX\xE1\xADL\x80\xE8V\x3C\xC6\xA8\xDBH\x2632\x18\xA8x\x01\x08\x21\x8DS\x0B\xC8\xAF\x96KO\xCA2\xB0\xF1\xBD\x1Du\xA0\x86\x05\x92s\xB0\x92\xC4Bc\xF1w\x24S\x85\x09\x09C\xAE\x24\x90'
space     = b'BZh91AY\x26SY\x94\x3A\xE2I\x00\x00\x21\x19\x80P\x81\x11\x00\xAFg\x9E\xA0 \x00hE\x3DM\xB5\x23\xD0\xD4\xD1\xE2\x8D\x06\xA9\xFA\x26S\xD4\xD3\x21\xA1\xEAi7h\x9B\x9A\x2B\xBF\x60\x22\xC5WX\xE1\xADL\x80\xE8V\x3C\xC6\xA8\xDBH\x2632\x18\xA8x\x01\x08\x21\x8DS\x0B\xC8\xAF\x96KO\xCA2\xB0\xF1\xBD\x1Du\xA0\x86\x05\x92s\xB0\x92\xC4Bc\xF1w\x24S\x85\x09\x09C\xAE\x24\x90'
ampersand = b'BZh91AY&SY\x94\x3a\xe2I\x00\x00\x21\x19\x80P\x81\x11\x00\xafg\x9e\xa0+\x00hE\x3dM\xb5\x23\xd0\xd4\xd1\xe2\x8d\x06\xa9\xfa\x26S\xd4\xd3\x21\xa1\xeai7h\x9b\x9a\x2b\xbf\x60\x22\xc5WX\xe1\xadL\x80\xe8V\x3c\xc6\xa8\xdbH\x2632\x18\xa8x\x01\x08\x21\x8dS\x0b\xc8\xaf\x96KO\xca2\xb0\xf1\xbd\x1du\xa0\x86\x05\x92s\xb0\x92\xc4Bc\xf1w\x24S\x85\x09\x09C\xae\x24\x90'
short     = b'BZh91AY\x26SY\x94\x3a\xe2I\x00\x00\x21\x19\x80P\x81\x11\x00\xafg\x9e\xa0+\x00hE'
double    = b'BZh91AY\\x26SY\\x94\\x3a\\xe2I\\x00\\x00\\x21\\x19\\x80P\\x81\\x11\\x00\\xafg\\x9e\\xa0+\\x00hE\\x3dM\\xb5\\x23\\xd0\\xd4\\xd1\\xe2\\x8d\\x06\\xa9\\xfa\\x26S\\xd4\\xd3\\x21\\xa1\\xeai7h\\x9b\\x9a\\x2b\\xbf\\x60\\x22\\xc5WX\\xe1\\xadL\\x80\\xe8V\\x3c\\xc6\\xa8\\xdbH\\x2632\\x18\\xa8x\\x01\\x08\\x21\\x8dS\\x0b\\xc8\\xaf\\x96KO\\xca2\\xb0\\xf1\\xbd\\x1du\\xa0\\x86\\x05\\x92s\\xb0\\x92\\xc4Bc\\xf1w\\x24S\\x85\\x09\\x09C\\xae\\x24\\x90'
trans0    = b'BZh91AY&SY\x94:\xe2I\x00\x00!\x19\x80P\x81\x11\x00\xafg\x9e\xa0+\x00hE=M\xb5#\xd0\xd4\xd1\xe2\x8d\x06\xa9\xfa&S\xd4\xd3!\xa1\xeai7h\x9b\x9a+\xbf`"\xc5WX\xe1\xadL\x80\xe8V<\xc6\xa8\xdbH&32\x18\xa8x\x01\x08!\x8dS\x0b\xc8\xaf\x96KO\xca2\xb0\xf1\xbd\x1du\xa0\x86\x05\x92s\xb0\x92\xc4Bc\xf1w$S\x85\x09\x09C\xae$\x90'
trans1    = b'BZh91AY&SY\x94:\xe2I\x00\x00!\x19\x80P\x81\x11\x00\xafg\x9e\xa0+\x00hE=M\xb5#\xd0\xd4\xd1\xe2\x8d\x06\xa9\xfa&S\xd4\xd3!\xa1\xeai7h\x9b\x9a+\xbf\x60"\xc5WX\xe1\xadL\x80\xe8V<\xc6\xa8\xdbH&32\x18\xa8x\x01\x08!\x8dS\x0b\xc8\xaf\x96KO\xca2\xb0\xf1\xbd\x1du\xa0\x86\x05\x92s\xb0\x92\xc4Bc\xf1w$S\x85\x09\x09C\xae$\x90'

import bz2
print bz2.decompress(space)
# Out:
# is it the 26th already? call his father and inform him that "the flowers are on their way". he'll understand.

# %%
print hex(ord('&'))
print chr(int('0x26',0))
# Out:
# 0x26
# &

# %%
import xmlrpclib

url = 'http://www.pythonchallenge.com/pc/phonebook.php'
server = xmlrpclib.ServerProxy(url)
print server.phone('Bert')
# Out:
# 555-ITALY

# %%
import xmlrpclib

url = 'http://www.pythonchallenge.com/pc/phonebook.php'
server = xmlrpclib.ServerProxy(url)
print server.phone('Leopold', )
# Out:
# 555-VIOLIN

# %%
# cookie:   info: the flowers are on their way
# balloons: brightness.html -> delta.txt

# %%
d_file = open('delta.txt')
delta = d_file.read()

full_lines = delta.split('\n')
lines = [full_line.split('   ') for full_line in full_lines]
left_lines  = filter(None, [line[0] for line in lines])
right_lines = filter(None, [line[len(line)-1].lstrip() for line in lines])


from pprint import pprint

double = []
l_out = []
r_out = []
r_offset = 0
l_offset = 0
for i in range(len(right_lines)):
    if i+r_offset >= len(right_lines) or i+l_offset >= len(left_lines):
        break
    if right_lines[i+r_offset] != left_lines[i+l_offset]:
        if right_lines[i+r_offset+1] == left_lines[i+l_offset]:
            r_out.append((right_lines[i+r_offset],i,r_offset))
            r_offset += 1
        elif right_lines[i+r_offset] == left_lines[i+l_offset+1]:
            l_out.append((left_lines[i+l_offset],i,l_offset))
            l_offset += 1
        elif right_lines[i+r_offset+1] == left_lines[i+l_offset+1]:
            r_out.append((right_lines[i+r_offset],i,r_offset))
            r_offset += 1
            l_out.append((left_lines[i+l_offset],i,l_offset))
            l_offset += 1
        else:
            print i, l_offset, r_offset
            break
    else:
        double.append(right_lines[i+r_offset])
# pprint(l_out)
# pprint(r_out)

clean_l = [x[0] for x in l_out]
int_list = [int(x, 16) for x in str.join(' ', clean_l).split(' ')]
b_arr = bytearray(int_list)

clean_r = [x[0] for x in r_out]
int_list_r = [int(x, 16) for x in str.join(' ', clean_r).split(' ')]
b_arr_r = bytearray(int_list_r)

int_list_d = [int(x, 16) for x in str.join(' ', double).split(' ')]
b_arr_d = bytearray(int_list_d)

# pprint(int_list_d)
seventeen_val = 100

cleaned_d = []
for i in range(len(int_list_d)-5):
    if i >= len(int_list_d):
        break
    if int_list_d[i] == 17 and int_list_d[i+4] == 17:
        this_int = 17
        # pprint(int_list_d[i-5:i+5])
        while this_int == 17:
            del int_list_d[i+seventeen_val]
            this_int = int_list_d[i+seventeen_val]
        # pprint(int_list_d[i-5:i+5])
    if int_list_d[i] == 81 and int_list_d[i+4] == 20 and False: #81, 20, 69
        this_int = 81
        while this_int in [81, 20, 69]:
            del int_list_d[i+3]
            this_int = int_list_d[i+3]
            
cleaned_d = bytearray(int_list_d)
# pprint(int_list_d)
    
# import os
import io
import Image
# from array import array

# def readimage(path):
#     count = os.stat(path).st_size / 2
#     with open(path, "rb") as f:
#         return bytearray(f.read())

# bytes = readimage(path+extension)
image = Image.open(io.BytesIO(b_arr))
image.save('test.png')
image2 = Image.open(io.BytesIO(b_arr_r))
image2.save('test2.png')

image3 = Image.open(io.BytesIO(cleaned_d))
print(image3)
# image3.show()

image3.LOAD_TRUNCATED_IMAGES = True
image3.save('test3.png')
# Out:
# <PngImagePlugin.PngImageFile image mode=RGB size=650x200 at 0x76B56C8>
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-b45398a66099> in <module>()
#      93
#      94 image3.LOAD_TRUNCATED_IMAGES = True
# ---> 95 image3.save('test3.png')
#
# C:\Users\Kibo\Anaconda3\envs\py27\lib\site-packages\PIL\Image.pyc in save(self, fp, format, **params)
#    1404
#    1405         # may mutate self!
# -> 1406         self.load()
#    1407
#    1408         self.encoderinfo = params
#
# C:\Users\Kibo\Anaconda3\envs\py27\lib\site-packages\PIL\ImageFile.pyc in load(self)
#     213
#     214         if not self.map and e < 0:
# --> 215             raise_ioerror(e)
#     216
#     217         # post processing
#
# C:\Users\Kibo\Anaconda3\envs\py27\lib\site-packages\PIL\ImageFile.pyc in raise_ioerror(error)
#      50     if not message:
# ...

# %%
import gzip, difflib

data = gzip.open("deltas.gz")
d1, d2 = [], []
for line in data:
    d1.append(line[:53].decode()+"\n")
    d2.append(line[56:].decode())


compare = difflib.Differ().compare(d1, d2)

f = open("f.png", "wb")
f1 = open("f1.png", "wb")
f2 = open("f2.png", "wb")

for line in compare:
    bs = bytes([int(o, 16) for o in line[2:].strip().split(" ") if o])
    if line[0] == '+':
        f1.write(bs)
    elif line[0] == '-':
        f2.write(bs)
    else:
        f.write(bs)

f.close()
f1.close()
f2.close()

# http://www.pythonchallenge.com/pc/hex/bin.html

# %%
import base64
import struct
import wave

encoded = open('base64.txt').read()

data = base64.b64decode(encoded)
# data_0 = data[1::2]
# data_1 = data[::2]

# data_0_hex = "".join([hex(ord(x))[2:] for x in filter(lambda x: ord(x) <= 0xf, data_even)]).encode("utf-8")

# f = open("india_0_hex.txt", 'wb')
# f.write(data_0_hex)

# f = open("india_0.txt", "wb")
# f.write(data_even)
# f.close()

# f = open("india_1.txt", "wb")
# f.write(data_odd)
# f.close()

f = open("indian.wav", "wb")
f.write(data)
f.close()

w=wave.open('indian.wav')
w2=wave.open('endian.wav','w')
w2.setnchannels(w.getnchannels())
print(w.getchannels())
w2.setsampwidth(w.getsampwidth())
w2.setframerate(w.getframerate())
frm=w.readframes(w.getnframes())

w2.setparams(w.getparams())
for i in range(w.getnframes()):
    reverse.writeframes(w.readframes(1)[::-1])


w.close()
w2.close()
# Out:
# Exception wave.Error: Error('sample width not specified',) in <bound method Wave_write.__del__ of <wave.Wave_write instance at 0x000000000657F588>> ignored
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-6a9e284e6011> in <module>()
#      29 w2=wave.open('endian.wav','w')
#      30 w2.setnchannels(w.getnchannels())
# ---> 31 print(w.getchannels())
#      32 w2.setsampwidth(w.getsampwidth())
#      33 w2.setframerate(w.getframerate())
#
# AttributeError: Wave_read instance has no attribute 'getchannels'

# %%
w = wave.open('indian.wav', 'rb')

h = wave.open("result.wav", "wb")

print(w.getnchannels())
print(w.getsampwidth())
print(w.getframerate())
h.setnchannels(w.getnchannels())
h.setsampwidth(w.getsampwidth()//2)
h.setframerate(w.getframerate()*2)
frames = w.readframes(w.getnframes())
wave.big_endiana = 1
h.writeframes(frames)

h.close()
# Out:
# 1
# 2
# 11025
